# %%
import pandas as py
import numpy as np
import matplotlib.pyplot as plt

# %%
df = py.read_csv("/home/rahmat/Downloads/tvmarketing.csv")
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
x1 = df['TV']
x0 = np.ones(len(x1))
X = np.array([x0,x1]).T
Y = df['Sales']
theta = np.ones(X.shape[1])

# %%
plt.scatter(df['TV'],Y)
plt.show()

# %%
x_transpose = X.T
x_inverse = np.linalg.pinv(x_transpose.dot(X))
x_transpose_y = x_transpose.dot(Y)
normal_equaction = x_inverse.dot(x_transpose_y)
plt.scatter(x1, Y)
plt.plot(x1,X.dot(normal_equaction) , label='Plots the line predicted by the normal equation solution ')
plt.title("TV vs Sales")
plt.xlabel("TV")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, Y)
plt.scatter(x1, Y)
a = model.predict(X)
print('model cofecient :',model.coef_)
plt.plot(x1,a , label='Plots the line predicted by the LinearRegression model ')
plt.title("TV vs Sales")
plt.xlabel("TV")
plt.ylabel("Sales")
plt.legend()
plt.show()
# Out:
# model cofecient : [0.         0.04753664]
